# %%
# 1. CHIAMARE GLI ATTREZZI
import pandas as pd
import cleaning_functions as cf # Qui diciamo: "Prendi le funzioni dal mio file"

# 2. CREARE IL PROBLEMA (Un DataFrame molto sporco)
# Immagina che questo sia un file Excel fatto male che ti ha dato un collega
raw_data = {
    "  NOME utente!! ": ["Mario", "Luigi"],
    "Data.Di.Nascita": ["1985-01-01", "1990-05-12"],
    "Prezzo ($)": [100, 200]
}
df_messy = pd.DataFrame(raw_data)

print("--- NOMI PRIMA DELLA CURA ---")
print(df_messy.columns.tolist())

# 3. RISOLVERE IL PROBLEMA
# Usiamo la tua funzione magica
df_clean = cf.clean_column_names(df_messy)

print("\n--- NOMI DOPO LA CURA ---")
print(df_clean.columns.tolist())
# Out:
# --- NOMI PRIMA DELLA CURA ---
# ['  NOME utente!! ', 'Data.Di.Nascita', 'Prezzo ($)']
#
# --- NOMI DOPO LA CURA ---
# ['nome_utente', 'data_di_nascita', 'prezzo']

# %%
print(df_clean.columns)
# Out:
# Index(['nome_utente', 'data_di_nascita', 'prezzo'], dtype='object')
